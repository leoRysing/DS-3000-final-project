# %%
import pandas as pd

# %%
diversity = pd.read_csv("raw/diversity_school.csv")
diversity
# Out:
#                                                  name  total_enrollment  \
# 0                       University of Phoenix-Arizona            195059
# 1                       University of Phoenix-Arizona            195059
# 2                       University of Phoenix-Arizona            195059
# 3                       University of Phoenix-Arizona            195059
# 4                       University of Phoenix-Arizona            195059
# ...                                               ...               ...
# 50650  ITT Technical Institute at Cedar Rapids (Iowa)                 1
# 50651  ITT Technical Institute at Cedar Rapids (Iowa)                 1
# 50652  ITT Technical Institute at Cedar Rapids (Iowa)                 1
# 50653  ITT Technical Institute at Cedar Rapids (Iowa)                 1
# 50654  ITT Technical Institute at Cedar Rapids (Iowa)                 1
#
#          state                         category  enrollment
# 0      Arizona                            Women      134722
# 1      Arizona  American Indian / Alaska Native         876
# 2      Arizona                            Asian        1959
# 3      Arizona                            Black       31455
# 4      Arizona                         Hispanic       13984
# ...        ...                              ...         ...
# 50650     Iowa                            White           1
# 50651     Iowa                Two Or More Races           0
# 50652     Iowa                          Unknown           0
# 50653     Iowa             Non-Resident Foreign           0
# 50654     Iowa                   Total Minority           0
#
# [50655 rows x 5 columns]

# %%
diversity.groupby("category").count()
# Out:
#                                     name  total_enrollment  state  enrollment
# category
# American Indian / Alaska Native     4574              4605   4574        4605
# Asian                               4574              4605   4574        4605
# Black                               4574              4605   4574        4605
# Hispanic                            4574              4605   4574        4605
# Native Hawaiian / Pacific Islander  4574              4605   4574        4605
# Non-Resident Foreign                4574              4605   4574        4605
# Total Minority                      4574              4605   4574        4605
# Two Or More Races                   4574              4605   4574        4605
# Unknown                             4574              4605   4574        4605
# White                               4574              4605   4574        4605
# Women                               4574              4605   4574        4605

# %%
tuition_cost = pd.read_csv("raw/tuition_cost.csv")
tuition_cost
# Out:
#                                       name           state state_code  \
# 0                   Aaniiih Nakoda College         Montana         MT
# 1             Abilene Christian University           Texas         TX
# 2     Abraham Baldwin Agricultural College         Georgia         GA
# 3                          Academy College       Minnesota         MN
# 4                Academy of Art University      California         CA
# ...                                    ...             ...        ...
# 2968                York Technical College  South Carolina         SC
# 2969                  Young Harris College         Georgia         GA
# 2970           Youngstown State University            Ohio         OH
# 2971                          Yuba College      California         CA
# 2972                    Zane State College            Ohio         OH
#
#             type degree_length  room_and_board  in_state_tuition  \
# 0         Public        2 Year             NaN              2380
# 1        Private        4 Year         10350.0             34850
# 2         Public        2 Year          8474.0              4128
# 3     For Profit        2 Year             NaN             17661
# 4     For Profit        4 Year         16648.0             27810
# ...          ...           ...             ...               ...
# 2968      Public        2 Year             NaN              5740
# 2969     Private        4 Year         12372.0             29117
# 2970      Public        4 Year          9400.0              8950
# 2971      Public        2 Year             NaN              1400
# 2972      Public        2 Year             NaN              5070
#
#       in_state_total  out_of_state_tuition  out_of_state_total
# 0               2380                  2380                2380
# 1              45200                 34850               45200
# 2              12602                 12550               21024
# 3              17661                 17661               17661
# 4              44458                 27810               44458
# ...              ...                   ...                 ...
# 2968            5740                 12190               12190
# 2969           41489                 29117               41489
# 2970           18350                 14950               24350
# 2971            1400                  8420                8420
# 2972            5070                  9930                9930
#
# [2973 rows x 10 columns]

# %%
tuition_by_incom = pd.read_csv("raw/tuition_income.csv")
tuition_by_incom
# Out:
#                                      name state  total_price  year  \
# 0       Piedmont International University    NC        20174  2016
# 1       Piedmont International University    NC        20174  2016
# 2       Piedmont International University    NC        20174  2016
# 3       Piedmont International University    NC        20174  2016
# 4       Piedmont International University    NC        20514  2017
# ...                                   ...   ...          ...   ...
# 209007           Alabama A & M University    AL        23462  2018
# 209008           Alabama A & M University    AL        23462  2018
# 209009           Alabama A & M University    AL        23462  2018
# 209010           Alabama A & M University    AL        23462  2018
# 209011           Alabama A & M University    AL        23462  2018
#
#             campus     net_cost         income_lvl
# 0        On Campus  11475.00000        0 to 30,000
# 1        On Campus  11451.00000   30,001 to 48,000
# 2        On Campus  16229.00000   48_001 to 75,000
# 3        On Campus  15592.00000  75,001 to 110,000
# 4        On Campus  11668.39249        0 to 30,000
# ...            ...          ...                ...
# 209007  Off Campus  15089.45111        0 to 30,000
# 209008  Off Campus  14810.60535   30,001 to 48,000
# 209009  Off Campus  17167.46710   48_001 to 75,000
# 209010  Off Campus  17558.05619  75,001 to 110,000
# 209011  Off Campus  19433.08888       Over 110,000
#
# [209012 rows x 7 columns]

# %%
history = pd.read_csv("raw/historical_tuition.csv")
history
# Out:
#                  type     year     tuition_type  tuition_cost
# 0    All Institutions  1985-86     All Constant         10893
# 1    All Institutions  1985-86  4 Year Constant         12274
# 2    All Institutions  1985-86  2 Year Constant          7508
# 3    All Institutions  1985-86      All Current          4885
# 4    All Institutions  1985-86   4 Year Current          5504
# ..                ...      ...              ...           ...
# 265           Private  2016-17  4 Year Constant         41468
# 266           Private  2016-17  2 Year Constant         24882
# 267           Private  2016-17      All Current         40925
# 268           Private  2016-17   4 Year Current         41468
# 269           Private  2016-17   2 Year Current         24882
#
# [270 rows x 4 columns]

# %%
tuition_by_incom_0To30000 = tuition_by_incom[tuition_by_incom["income_lvl"] == "0 to 30,000"]
tuition_by_incom_0To30000 = tuition_by_incom_0To30000.drop(labels = ["state", "income_lvl"], axis = 1)
new_Names_block1 = {"net_cost":"net_cost_0_to_30"}
tuition_by_incom_0To30000 = tuition_by_incom_0To30000.rename(columns=new_Names_block1)
tuition_by_incom_0To30000
# Out:
#                                      name  total_price  year      campus  \
# 0       Piedmont International University        20174  2016   On Campus
# 4       Piedmont International University        20514  2017   On Campus
# 9       Piedmont International University        20829  2018   On Campus
# 14      Piedmont International University        23000  2016  Off Campus
# 18      Piedmont International University        26430  2017  Off Campus
# ...                                   ...          ...   ...         ...
# 208987           Alabama A & M University        23763  2014  Off Campus
# 208992           Alabama A & M University        22896  2015  Off Campus
# 208997           Alabama A & M University        22886  2016  Off Campus
# 209002           Alabama A & M University        22416  2017  Off Campus
# 209007           Alabama A & M University        23462  2018  Off Campus
#
#         net_cost_0_to_30
# 0            11475.00000
# 4            11668.39249
# 9            11847.56494
# 14           11475.00000
# 18           11668.39249
# ...                  ...
# 208987       13075.00000
# 208992       15043.00000
# 208997       14719.00000
# 209002       14828.97767
# 209007       15089.45111
#
# [44969 rows x 5 columns]

# %%
tuition_by_incom_300001 = tuition_by_incom[tuition_by_incom["income_lvl"] == "30,001 to 48,000"]
tuition_by_incom_300001 = tuition_by_incom_300001.drop(labels = ["state", "income_lvl"], axis = 1)
new_Names_block2 = {"net_cost":"net_cost_30_to_48"}
tuition_by_incom_300001 = tuition_by_incom_300001.rename(columns=new_Names_block2)
tuition_by_incom_300001.head(15)
# Out:
#                                      name  total_price  year      campus  \
# 1       Piedmont International University        20174  2016   On Campus
# 5       Piedmont International University        20514  2017   On Campus
# 10      Piedmont International University        20829  2018   On Campus
# 15      Piedmont International University        23000  2016  Off Campus
# 19      Piedmont International University        26430  2017  Off Campus
# 24      Piedmont International University        26870  2018  Off Campus
# 29            Kaplan University-Milwaukee        22413  2017  Off Campus
# 34            Kaplan University-Milwaukee        22492  2018  Off Campus
# 39         Kaplan University-Indianapolis        22413  2017  Off Campus
# 44         Kaplan University-Indianapolis        22492  2018  Off Campus
# 49      Chamberlain University-California        39475  2017  Off Campus
# 54      Chamberlain University-California        39815  2018  Off Campus
# 60  Chamberlain University-North Carolina        37767  2017  Off Campus
# 65  Chamberlain University-North Carolina        37927  2018  Off Campus
# 70               Clovis Community College        14622  2016  Off Campus
#
#     net_cost_30_to_48
# 1         11451.00000
# 5         11643.98800
# 10        11822.78571
# 15        11451.00000
# 19        11643.98800
# 24        11822.78571
# 29            0.00000
# 34            0.00000
# 39            0.00000
# 44            0.00000
# 49            0.00000
# 54            0.00000
# 60            0.00000
# 65            0.00000
# 70         2654.00000

# %%
tuition_by_incom_48001 = tuition_by_incom[tuition_by_incom["income_lvl"] == "48_001 to 75,000"]
tuition_by_incom_48001 = tuition_by_incom_48001.drop(labels = ["state", "income_lvl"], axis = 1)
new_Names_block3 = {"net_cost":"net_cost_48_to_75"}
tuition_by_incom_48001 = tuition_by_incom_48001.rename(columns=new_Names_block3)
tuition_by_incom_48001
# Out:
#                                      name  total_price  year      campus  \
# 2       Piedmont International University        20174  2016   On Campus
# 6       Piedmont International University        20514  2017   On Campus
# 11      Piedmont International University        20829  2018   On Campus
# 16      Piedmont International University        23000  2016  Off Campus
# 20      Piedmont International University        26430  2017  Off Campus
# ...                                   ...          ...   ...         ...
# 208989           Alabama A & M University        23763  2014  Off Campus
# 208994           Alabama A & M University        22896  2015  Off Campus
# 208999           Alabama A & M University        22886  2016  Off Campus
# 209004           Alabama A & M University        22416  2017  Off Campus
# 209009           Alabama A & M University        23462  2018  Off Campus
#
#         net_cost_48_to_75
# 2             16229.00000
# 6             16502.51343
# 11            16755.91558
# 16            16229.00000
# 20            16502.51343
# ...                   ...
# 208989        15857.00000
# 208994        17335.00000
# 208999        16746.00000
# 209004        16871.12304
# 209009        17167.46710
#
# [42600 rows x 5 columns]

# %%
tuition_by_incom_75001 = tuition_by_incom[tuition_by_incom["income_lvl"] == "75,001 to 110,000"]
tuition_by_incom_75001 = tuition_by_incom_75001.drop(labels = ["state", "income_lvl"], axis = 1)
new_Names_block4 = {"net_cost":"net_cost_75_to_110"}
tuition_by_incom_75001 = tuition_by_incom_75001.rename(columns=new_Names_block4)
tuition_by_incom_75001
# Out:
#                                      name  total_price  year      campus  \
# 3       Piedmont International University        20174  2016   On Campus
# 7       Piedmont International University        20514  2017   On Campus
# 12      Piedmont International University        20829  2018   On Campus
# 17      Piedmont International University        23000  2016  Off Campus
# 21      Piedmont International University        26430  2017  Off Campus
# ...                                   ...          ...   ...         ...
# 208990           Alabama A & M University        23763  2014  Off Campus
# 208995           Alabama A & M University        22896  2015  Off Campus
# 209000           Alabama A & M University        22886  2016  Off Campus
# 209005           Alabama A & M University        22416  2017  Off Campus
# 209010           Alabama A & M University        23462  2018  Off Campus
#
#         net_cost_75_to_110
# 3              15592.00000
# 7              15854.77783
# 12             16098.23377
# 17             15592.00000
# 21             15854.77783
# ...                    ...
# 208990         16022.00000
# 208995         19562.00000
# 209000         17127.00000
# 209005         17254.96981
# 209010         17558.05619
#
# [40403 rows x 5 columns]

# %%
tuition_by_incom_111000 = tuition_by_incom[tuition_by_incom["income_lvl"] == "Over 110,000"]
tuition_by_incom_111000 = tuition_by_incom_111000.drop(labels = ["state", "income_lvl"], axis = 1)
new_Names_block5 = {"net_cost":"net_cost_over_110"}
tuition_by_incom_111000 = tuition_by_incom_111000.rename(columns=new_Names_block5)
tuition_by_incom_111000
# Out:
#                                      name  total_price  year      campus  \
# 8       Piedmont International University        20514  2017   On Campus
# 13      Piedmont International University        20829  2018   On Campus
# 22      Piedmont International University        26430  2017  Off Campus
# 27      Piedmont International University        26870  2018  Off Campus
# 32            Kaplan University-Milwaukee        22413  2017  Off Campus
# ...                                   ...          ...   ...         ...
# 208991           Alabama A & M University        23763  2014  Off Campus
# 208996           Alabama A & M University        22896  2015  Off Campus
# 209001           Alabama A & M University        22886  2016  Off Campus
# 209006           Alabama A & M University        22416  2017  Off Campus
# 209011           Alabama A & M University        23462  2018  Off Campus
#
#         net_cost_over_110
# 8                 0.00000
# 13                0.00000
# 22                0.00000
# 27                0.00000
# 32                0.00000
# ...                   ...
# 208991        14646.00000
# 208996        18865.00000
# 209001        18956.00000
# 209006        19097.63576
# 209011        19433.08888
#
# [37656 rows x 5 columns]

# %%
from functools import reduce

# %%
data_frames = [tuition_by_incom_0To30000, tuition_by_incom_300001, 
              tuition_by_incom_48001, tuition_by_incom_75001, tuition_by_incom_111000]


tuit_inc_merged = reduce(lambda  left,right: pd.merge(left,right,
                                                      on=["name", "year", "campus", "total_price"],
                                                      how='outer'), data_frames)
#tuit_inc_merged = pd.merge(tuition_by_incom_0To30000, 
                       #    tuition_by_incom_300001, on=["name", "year", "campus", "total_price"],
                        #  how="inner")
tuit_inc_merged
# Out:
#                                          name  total_price  year      campus  \
# 0           Piedmont International University        20174  2016   On Campus
# 1           Piedmont International University        20514  2017   On Campus
# 2           Piedmont International University        20829  2018   On Campus
# 3           Piedmont International University        23000  2016  Off Campus
# 4           Piedmont International University        26430  2017  Off Campus
# ...                                       ...          ...   ...         ...
# 40412668  Circle in the Square Theatre School        40940  2013  Off Campus
# 40412669           Lutheran School of Nursing        23229  2016   On Campus
# 40412670           Lutheran School of Nursing        28698  2016  Off Campus
# 40412671                      Laboure College        50498  2016  Off Campus
# 40412672               Nazarene Bible College        25950  2012  Off Campus
#
#           net_cost_0_to_30  net_cost_30_to_48  net_cost_48_to_75  \
# 0              11475.00000        11451.00000        16229.00000
# 1              11668.39249        11643.98800        16502.51343
# 2              11847.56494        11822.78571        16755.91558
# 3              11475.00000        11451.00000        16229.00000
# 4              11668.39249        11643.98800        16502.51343
# ...                    ...                ...                ...
# 40412668               NaN                NaN                NaN
# 40412669               NaN                NaN                NaN
# 40412670               NaN                NaN                NaN
# 40412671               NaN                NaN                NaN
# 40412672               NaN                NaN                NaN
#
#           net_cost_75_to_110  net_cost_over_110
# 0                15592.00000                NaN
# 1                15854.77783                0.0
# 2                16098.23377                0.0
# 3                15592.00000                NaN
# 4                15854.77783                0.0
# ...                      ...                ...
# 40412668                 NaN            40940.0
# 40412669                 NaN            23229.0
# 40412670                 NaN            23229.0
# 40412671                 NaN            38498.0
# 40412672                 NaN            25950.0
#
# [40412673 rows x 9 columns]

# %%
tuit_inc_merged = tuit_inc_merged.dropna()
tuit_inc_merged = tuit_inc_merged.drop_duplicates()
tuit_inc_merged
# Out:
#                                        name  total_price  year      campus  \
# 1         Piedmont International University        20514  2017   On Campus
# 2         Piedmont International University        20829  2018   On Campus
# 4         Piedmont International University        26430  2017  Off Campus
# 5         Piedmont International University        26870  2018  Off Campus
# 6               Kaplan University-Milwaukee        22413  2017  Off Campus
# ...                                     ...          ...   ...         ...
# 40412315           Alabama A & M University        23763  2014  Off Campus
# 40412316           Alabama A & M University        22896  2015  Off Campus
# 40412317           Alabama A & M University        22886  2016  Off Campus
# 40412318           Alabama A & M University        22416  2017  Off Campus
# 40412319           Alabama A & M University        23462  2018  Off Campus
#
#           net_cost_0_to_30  net_cost_30_to_48  net_cost_48_to_75  \
# 1              11668.39249        11643.98800        16502.51343
# 2              11847.56494        11822.78571        16755.91558
# 4              11668.39249        11643.98800        16502.51343
# 5              11847.56494        11822.78571        16755.91558
# 6                  0.00000            0.00000            0.00000
# ...                    ...                ...                ...
# 40412315       13075.00000        12458.00000        15857.00000
# 40412316       15043.00000        15491.00000        17335.00000
# 40412317       14719.00000        14447.00000        16746.00000
# 40412318       14828.97767        14554.94534        16871.12304
# 40412319       15089.45111        14810.60535        17167.46710
#
#           net_cost_75_to_110  net_cost_over_110
# 1                15854.77783            0.00000
# 2                16098.23377            0.00000
# 4                15854.77783            0.00000
# 5                16098.23377            0.00000
# 6                    0.00000            0.00000
# ...                      ...                ...
# 40412315         16022.00000        14646.00000
# 40412316         19562.00000        18865.00000
# 40412317         17127.00000        18956.00000
# 40412318         17254.96981        19097.63576
# 40412319         17558.05619        19433.08888
#
# [58620 rows x 9 columns]

# %%
#tuit_inc_merged
tuit_inc_merged.reset_index()
tuit_inc_merged.head(25)
# Out:
#                                              name  total_price  year  \
# 1               Piedmont International University        20514  2017
# 2               Piedmont International University        20829  2018
# 4               Piedmont International University        26430  2017
# 5               Piedmont International University        26870  2018
# 6                     Kaplan University-Milwaukee        22413  2017
# 7                     Kaplan University-Milwaukee        22492  2018
# 8                  Kaplan University-Indianapolis        22413  2017
# 9                  Kaplan University-Indianapolis        22492  2018
# 10              Chamberlain University-California        39475  2017
# 11              Chamberlain University-California        39815  2018
# 12          Chamberlain University-North Carolina        37767  2017
# 13          Chamberlain University-North Carolina        37927  2018
# 14                       Clovis Community College        14622  2016
# 15                       Clovis Community College        14360  2017
# 16                       Clovis Community College        16576  2018
# 17                     Northeast Lakeview College        20802  2017
# 18                     Northeast Lakeview College        20830  2018
# 19  Indiana Wesleyan University-National & Global        28484  2016
# 20  Indiana Wesleyan University-National & Global        28250  2017
# 21  Indiana Wesleyan University-National & Global        28178  2018
# 23                         Seattle Film Institute        49076  2017
# 24                         Seattle Film Institute        49076  2018
# 25                 Yeshiva Gedolah Shaarei Shmuel        14010  2017
# 26                 Yeshiva Gedolah Shaarei Shmuel        14900  2018
# 27                    Beth Medrash of Asbury Park        16300  2017
#
#         campus  net_cost_0_to_30  net_cost_30_to_48  net_cost_48_to_75  \
# 1    On Campus      11668.392490       11643.988000       16502.513430
# 2    On Campus      11847.564940       11822.785710       16755.915580
# 4   Off Campus      11668.392490       11643.988000       16502.513430
# 5   Off Campus      11847.564940       11822.785710       16755.915580
# 6   Off Campus          0.000000           0.000000           0.000000
# 7   Off Campus          0.000000           0.000000           0.000000
# 8   Off Campus          0.000000           0.000000           0.000000
# 9   Off Campus          0.000000           0.000000           0.000000
# 10  Off Campus          0.000000           0.000000           0.000000
# 11  Off Campus          0.000000           0.000000           0.000000
# 12  Off Campus          0.000000           0.000000           0.000000
# 13  Off Campus          0.000000           0.000000           0.000000
# 14  Off Campus       2271.000000        2654.000000        2761.000000
# 15  Off Campus       2230.307755        2606.445083        2711.527835
# 16  Off Campus       2574.483381        3008.665299        3129.964164
# 17  Off Campus          0.000000           0.000000           0.000000
# 18  Off Campus          0.000000           0.000000           0.000000
# 19  Off Campus      22205.000000       22976.000000       24779.000000
# 20  Off Campus      22022.582850       22787.248980       24575.437090
# 21  Off Campus      21966.454500       22729.171750       24512.802350
# 23  Off Campus      42815.637860           0.000000           0.000000
# 24  Off Campus      42815.637860           0.000000           0.000000
# 25   On Campus          0.000000        7325.000000        7376.000000
# 26   On Campus          0.000000        7790.328337        7844.568166
# 27   On Campus          0.000000           0.000000           0.000000
#
#     net_cost_75_to_110  net_cost_over_110
# 1         15854.777830           0.000000
# 2         16098.233770           0.000000
# 4         15854.777830           0.000000
# 5         16098.233770           0.000000
# 6             0.000000           0.000000
# 7             0.000000           0.000000
# 8             0.000000           0.000000
# 9             0.000000           0.000000
# 10            0.000000           0.000000
# 11            0.000000           0.000000
# 12        26527.778200           0.000000
# 13        26640.163200           0.000000
# 14         2821.000000        8365.000000
# 15         2770.452742        8215.114211
# 16         3197.982219        9482.850499
# 17            0.000000           0.000000
# 18            0.000000           0.000000
# 19        26811.000000       27707.000000
# 20        26590.743930       27479.383160
# 21        26522.972830       27409.347210
# 23            0.000000           0.000000
# 24            0.000000           0.000000
# 25            0.000000           0.000000
# 26            0.000000           0.000000
# 27        12250.000000           0.000000

# %%
tuit_inc_merged = tuit_inc_merged.reset_index()

# %%
tuit_inc_merged
# Out:
#           index                               name  total_price  year  \
# 0             1  Piedmont International University        20514  2017
# 1             2  Piedmont International University        20829  2018
# 2             4  Piedmont International University        26430  2017
# 3             5  Piedmont International University        26870  2018
# 4             6        Kaplan University-Milwaukee        22413  2017
# ...         ...                                ...          ...   ...
# 58615  40412315           Alabama A & M University        23763  2014
# 58616  40412316           Alabama A & M University        22896  2015
# 58617  40412317           Alabama A & M University        22886  2016
# 58618  40412318           Alabama A & M University        22416  2017
# 58619  40412319           Alabama A & M University        23462  2018
#
#            campus  net_cost_0_to_30  net_cost_30_to_48  net_cost_48_to_75  \
# 0       On Campus       11668.39249        11643.98800        16502.51343
# 1       On Campus       11847.56494        11822.78571        16755.91558
# 2      Off Campus       11668.39249        11643.98800        16502.51343
# 3      Off Campus       11847.56494        11822.78571        16755.91558
# 4      Off Campus           0.00000            0.00000            0.00000
# ...           ...               ...                ...                ...
# 58615  Off Campus       13075.00000        12458.00000        15857.00000
# 58616  Off Campus       15043.00000        15491.00000        17335.00000
# 58617  Off Campus       14719.00000        14447.00000        16746.00000
# 58618  Off Campus       14828.97767        14554.94534        16871.12304
# 58619  Off Campus       15089.45111        14810.60535        17167.46710
#
#        net_cost_75_to_110  net_cost_over_110
# 0             15854.77783            0.00000
# 1             16098.23377            0.00000
# 2             15854.77783            0.00000
# 3             16098.23377            0.00000
# 4                 0.00000            0.00000
# ...                   ...                ...
# 58615         16022.00000        14646.00000
# 58616         19562.00000        18865.00000
# 58617         17127.00000        18956.00000
# 58618         17254.96981        19097.63576
# 58619         17558.05619        19433.08888
#
# [58620 rows x 10 columns]

# %%
tuit_small_inc_merged = tuit_inc_merged[tuit_inc_merged["year"] >= 2016]

# %%
tuit_small_inc_merged.to_csv("raw/tuition_income_merged_2016_to_2018.csv")

# %%
income_and_cost = pd.merge(tuit_small_inc_merged, tuition_cost, on="name")
income_and_cost
# Out:
#           index                                 name  total_price  year  \
# 0             1    Piedmont International University        20514  2017
# 1             2    Piedmont International University        20829  2018
# 2             4    Piedmont International University        26430  2017
# 3             5    Piedmont International University        26870  2018
# 4            14             Clovis Community College        14622  2016
# ...         ...                                  ...          ...   ...
# 10926  40412292  University of Alabama at Birmingham        26096  2017
# 10927  40412293  University of Alabama at Birmingham        26336  2018
# 10928  40412300  University of Alabama at Birmingham        25808  2016
# 10929  40412301  University of Alabama at Birmingham        26096  2017
# 10930  40412302  University of Alabama at Birmingham        26336  2018
#
#            campus  net_cost_0_to_30  net_cost_30_to_48  net_cost_48_to_75  \
# 0       On Campus       11668.39249        11643.98800        16502.51343
# 1       On Campus       11847.56494        11822.78571        16755.91558
# 2      Off Campus       11668.39249        11643.98800        16502.51343
# 3      Off Campus       11847.56494        11822.78571        16755.91558
# 4      Off Campus        2271.00000         2654.00000         2761.00000
# ...           ...               ...                ...                ...
# 10926   On Campus       15450.51457        16893.43893        19100.79975
# 10927   On Campus       15592.61004        17048.80471        19276.46621
# 10928  Off Campus       15280.00000        16707.00000        18890.00000
# 10929  Off Campus       15450.51457        16893.43893        19100.79975
# 10930  Off Campus       15592.61004        17048.80471        19276.46621
#
#        net_cost_75_to_110  net_cost_over_110           state state_code  \
# 0             15854.77783            0.00000  North Carolina         NC
# 1             16098.23377            0.00000  North Carolina         NC
# 2             15854.77783            0.00000  North Carolina         NC
# 3             16098.23377            0.00000  North Carolina         NC
# 4              2821.00000         8365.00000      New Mexico         NM
# ...                   ...                ...             ...        ...
# 10926         20051.28952        19885.45939         Alabama         AL
# 10927         20235.69746        20068.34222         Alabama         AL
# 10928         19830.00000        19666.00000         Alabama         AL
# 10929         20051.28952        19885.45939         Alabama         AL
# 10930         20235.69746        20068.34222         Alabama         AL
#
#           type degree_length  room_and_board  in_state_tuition  \
# 0      Private        4 Year          7810.0             10970
# 1      Private        4 Year          7810.0             10970
# 2      Private        4 Year          7810.0             10970
# 3      Private        4 Year          7810.0             10970
# 4       Public        2 Year             NaN              1296
# ...        ...           ...             ...               ...
# 10926   Public        4 Year          6400.0             10710
# 10927   Public        4 Year          6400.0             10710
# 10928   Public        4 Year          6400.0             10710
# 10929   Public        4 Year          6400.0             10710
# 10930   Public        4 Year          6400.0             10710
#
#        in_state_total  out_of_state_tuition  out_of_state_total
# 0               18780                 10970               18780
# 1               18780                 10970               18780
# 2               18780                 10970               18780
# 3               18780                 10970               18780
# 4                1296                  2904                2904
# ...               ...                   ...                 ...
# 10926           17110                 24630               31030
# 10927           17110                 24630               31030
# 10928           17110                 24630               31030
# 10929           17110                 24630               31030
# 10930           17110                 24630               31030
#
# [10931 rows x 19 columns]

# %%
income_and_cost.to_csv("raw/tuition_complete_merged.csv")

# %%
holisitc_merged = pd.merge(income_and_cost, )
